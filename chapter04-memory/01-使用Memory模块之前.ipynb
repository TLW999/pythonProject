# %%
import os
import dotenv
from langchain_core.messages import HumanMessage
from langchain_core.messages.ai import AIMessage
from langchain_core.prompts.chat import ChatPromptTemplate
from langchain_openai import ChatOpenAI
#1.获取大模型
dotenv.load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["OPENAI_BASE_URL"] = os.getenv("OPENAI_BASE_URL")

llm = ChatOpenAI(
    model_name="gpt-4o-mini",
    temperature=0.8,

)
# Out:
# D:\conda_envs\python313\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
def chat_with_model(answer):

    #2.提供提示词模板，ChatPromptTemplate
    prompt_template = ChatPromptTemplate.from_messages([
        ("system","你是一个人工智能助手"),
        ("human","{question}")
    ])

    while True:
        #3.获取Chain，并调用大模型得到响应
        chain = prompt_template | llm
        response = chain.invoke({"question": answer})

        #4.输出大模型的响应
        print(response.content)

        #5.继续获取用户的问题
        user_input = input("你还有什么问题吗？（输入'退出'，结束会话）")

        #6.指明退出循环的方式
        if(user_input == "退出"):
            break

        #7.将上述新生成的消息存放到提示词模板的消息队列中
        prompt_template.messages.append(AIMessage(content=response.content))
        prompt_template.messages.append(HumanMessage(content=user_input))

chat_with_model("你好，很高兴认识你")
# Out:
# 你好！我也很高兴认识你。有任何问题或者想聊的话题吗？
# 当然认识！李白是中国唐代著名的诗人，被誉为“诗仙”。他的诗作以豪放、奔放的风格著称，充满了对自然的热爱和对人生的感慨。李白的作品如《将进酒》、《庐山谣》、《月下独酌》等都是经典之作，对后世影响深远。你对李白的诗歌有什么特别喜欢的作品吗？
# 李白最著名的诗之一是《将进酒》。这首诗表达了他对人生的豪情壮志和及时行乐的态度。以下是这首诗的开头部分：
#
# 将进酒，杯莫停。
# 与君歌一曲，愿君多采撷。
# 酌贪泉而觉爽，处涸辙以犹欢。
#
# 整首诗充满了豪情，展现了李白对饮酒和生活的热爱。如果你想了解更多关于这首诗的内容或背景，随时可以问我！
